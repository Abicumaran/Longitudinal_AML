# %%
import os
import gzip
import shutil

# Define the directory containing the files
input_dir = "GSE235063_RAW"  # Replace with the actual folder path
output_dir = os.path.join(input_dir, "processed_data_csv")

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# File patterns to look for
file_patterns = ["processed_barcodes.tsv", "processed_genes.tsv", "processed_metadata.tsv", "processed_matrix.mtx"]

# Loop through files in the input directory
for filename in os.listdir(input_dir):
    # Check if the file matches any of the desired patterns
    if any(pattern in filename for pattern in file_patterns):
        file_path = os.path.join(input_dir, filename)
        output_file_path = os.path.join(output_dir, filename.replace(".tsv", ".csv").replace(".mtx", ".csv"))

        # Extract and convert gzipped files if necessary
        if filename.endswith(".gz"):
            with gzip.open(file_path, 'rt') as gz_file, open(output_file_path, 'w') as out_file:
                shutil.copyfileobj(gz_file, out_file)
        else:
            # For uncompressed files, copy them to the new location with a .csv extension
            shutil.copyfile(file_path, output_file_path)

print(f"Processed data has been extracted and saved to {output_dir}")
# Out:
# Processed data has been extracted and saved to GSE235063_RAW\processed_data_csv

# %%
import os
import gzip
from scipy.io import mmread
import pandas as pd

# Define input and output directories
input_dir = "GSE235063_RAW"  # Replace with your directory path
output_dir = os.path.join(input_dir, "processed_matrices_csv")
os.makedirs(output_dir, exist_ok=True)

# Process only the *_processed_matrix.mtx.gz files
for filename in os.listdir(input_dir):
    if filename.endswith("_processed_matrix.mtx.gz"):
        # Define file paths
        gz_file_path = os.path.join(input_dir, filename)
        decompressed_path = gz_file_path.replace(".gz", "")
        output_csv_path = os.path.join(output_dir, filename.replace(".mtx.gz", ".csv"))

        try:
            # Decompress the .gz file
            with gzip.open(gz_file_path, 'rt') as gz_file:
                with open(decompressed_path, 'w') as decompressed_file:
                    decompressed_file.write(gz_file.read())

            # Read the sparse matrix
            sparse_matrix = mmread(decompressed_path)
            # Convert to a dense DataFrame
            dense_matrix = pd.DataFrame(sparse_matrix.toarray())
            # Save the dense matrix as a CSV
            dense_matrix.to_csv(output_csv_path, index=False)
            print(f"Processed matrix saved: {output_csv_path}")

            # Clean up: Remove the temporary decompressed file
            os.remove(decompressed_path)

        except Exception as e:
            print(f"Error processing {gz_file_path}: {e}")

print(f"All processed matrices have been saved to {output_dir}")

# %%
import os
import pandas as pd

# Define the directory paths
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
genes_dir = "GSE235063_RAW"  # Directory containing *_processed_genes.tsv files

# Iterate through all processed matrix files
for matrix_file in os.listdir(processed_matrices_dir):
    if matrix_file.endswith("_processed_matrix.csv"):
        # Define file paths
        matrix_path = os.path.join(processed_matrices_dir, matrix_file)
        gene_file_name = matrix_file.replace("_processed_matrix.csv", "_processed_genes.tsv.gz")
        gene_file_path = os.path.join(genes_dir, gene_file_name)
        
        # Load the matrix file
        matrix_df = pd.read_csv(matrix_path)
        
        # Load the corresponding gene file
        if os.path.exists(gene_file_path):
            genes_df = pd.read_csv(gene_file_path, header=None, names=["Gene"])  # Assume no header in TSV
        else:
            print(f"Gene file missing for {matrix_file}")
            continue
        
        # Add the "Gene" column to the matrix
        matrix_df.insert(0, "Gene", genes_df["Gene"])
        
        # Rename all other column headers to "AML"
        matrix_df.columns = ["Gene"] + ["AML"] * (len(matrix_df.columns) - 1)
        
        # Save the updated matrix back to the same file
        matrix_df.to_csv(matrix_path, index=False)
        print(f"Updated matrix file: {matrix_path}")

print("All files updated.")
# Out:
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494257_AML16_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494258_AML16_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494259_AML16_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494260_AML6_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494261_AML6_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494262_AML6_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494263_AML2_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494264_AML2_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494265_AML2_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494266_AML15_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494267_AML15_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494268_AML15_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494271_AML7_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494272_AML7_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494273_AML7_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494274_AML8_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494275_AML8_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494276_AML8_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494279_AML5_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494280_AML5_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494281_AML5_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494286_AML27_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494287_AML27_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494288_AML27_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494289_AML9_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494290_AML9_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494291_AML9_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494292_AML10_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494293_AML10_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494294_AML10_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494295_AML11_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494296_AML11_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494297_AML11_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494300_AML22_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494301_AML22_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494302_AML22_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494303_AML21_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494304_AML21_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494305_AML21_REM_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494306_AML24_DX_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494307_AML24_REL_processed_matrix.csv
# Updated matrix file: GSE235063_RAW/processed_matrices_csv\GSM7494308_AML24_REM_processed_matrix.csv
# All files updated.

# %%
###LSTM
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
output_dir = "results/lstm_bdm_analysisV2"
os.makedirs(output_dir, exist_ok=True)

# Train LSTM and Extract Feature Importance
def train_lstm_and_extract_importance(sequences, labels, gene_names, patient):
    # Normalize data
    scaler = MinMaxScaler()
    sequences = scaler.fit_transform(sequences)

    # Reshape to (samples, timesteps, features)
    sequences = sequences.reshape((sequences.shape[0], sequences.shape[1], 1))

    # Generate dummy labels matching samples (one per row/gene)
    labels = np.random.randint(0, 3, size=sequences.shape[0])  # Placeholder for actual labels

    # 70:15:15 split (train, validation, test)
    split_1 = int(0.7 * len(sequences))
    split_2 = int(0.85 * len(sequences))
    X_train, X_val, X_test = (
        sequences[:split_1],
        sequences[split_1:split_2],
        sequences[split_2:],
    )
    y_train, y_val, y_test = labels[:split_1], labels[split_1:split_2], labels[split_2:]

    # Build LSTM model
    model = Sequential([
        LSTM(64, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=False),
        Dense(3, activation="softmax")
    ])
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

    # Train model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        verbose=1
    )

    # Save training metrics
    history_df = pd.DataFrame(history.history)
    history_df.to_csv(os.path.join(output_dir, f"{patient}_training_metrics.csv"), index=False)

    # Evaluate on test data
    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=["DX", "REL", "REM"])
    confusion = confusion_matrix(y_test, y_pred)

    # Save evaluation metrics
    with open(os.path.join(output_dir, f"{patient}_evaluation_metrics.txt"), "w") as f:
        f.write(f"Accuracy: {accuracy}\n")
        f.write(f"Classification Report:\n{report}\n")
        f.write(f"Confusion Matrix:\n{confusion}\n")

    # Extract feature importance from LSTM weights
    lstm_weights = model.layers[0].get_weights()[0]  # LSTM input weights
    feature_importance = np.mean(np.abs(lstm_weights), axis=(0, 1))  # Average importance across gates

    # Rank features by importance
    feature_ranking = pd.DataFrame({
        "Gene": gene_names,
        "Importance": feature_importance
    }).sort_values(by="Importance", ascending=False)

    return feature_ranking

# Process one patient at a time
def process_patient(patient, files):
    print(f"Processing {patient}...")

    # Load DX, REL, REM data
    dx_file = os.path.join(processed_matrices_dir, files.get("DX"))
    rel_file = os.path.join(processed_matrices_dir, files.get("REL"))
    rem_file = os.path.join(processed_matrices_dir, files.get("REM"))

    dx_df = pd.read_csv(dx_file)
    rel_df = pd.read_csv(rel_file)
    rem_df = pd.read_csv(rem_file)

    # Extract genes and samples
    common_genes = set(dx_df["Gene"]).intersection(rel_df["Gene"]).intersection(rem_df["Gene"])
    dx_df = dx_df[dx_df["Gene"].isin(common_genes)].set_index("Gene")
    rel_df = rel_df[rel_df["Gene"].isin(common_genes)].set_index("Gene")
    rem_df = rem_df[rem_df["Gene"].isin(common_genes)].set_index("Gene")

    # Combine DX, REL, REM into sequences (samples x timepoints)
    sequences = np.stack([dx_df.mean(axis=1).values, rel_df.mean(axis=1).values, rem_df.mean(axis=1).values], axis=1)
    labels = np.array([0, 1, 2])  # DX=0, REL=1, REM=2

    # Train LSTM and extract feature importance
    feature_ranking = train_lstm_and_extract_importance(sequences, labels, dx_df.index.tolist(), patient)

    # Save top 100 features
    top_100_features = feature_ranking.head(100)
    top_100_features.to_csv(os.path.join(output_dir, f"{patient}_top_100_features.csv"), index=False)

    print(f"Completed {patient}")

# Organize files by patient
file_groups = {}
for file in os.listdir(processed_matrices_dir):
    if not file.endswith("_processed_matrix.csv"):
        continue
    parts = file.split("_")
    patient, state = parts[1], parts[2]
    file_groups.setdefault(patient, {})[state] = file

# Run the analysis
for patient, files in file_groups.items():
    process_patient(patient, files)

print("LSTM feature importance analysis completed.")

# %%
##Bidirectional LSTM

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
output_dir = "results/bidirectional_lstm_analysis"
os.makedirs(output_dir, exist_ok=True)

# Train Bidirectional LSTM and Extract Feature Importance
def train_bilstm_and_extract_importance(sequences, labels, gene_names, patient):
    # Normalize data
    scaler = MinMaxScaler()
    sequences = scaler.fit_transform(sequences)

    # Reshape to (samples, timesteps, features)
    sequences = sequences.reshape((sequences.shape[0], sequences.shape[1], 1))

    # Generate dummy labels matching samples (one per row/gene)
    labels = np.random.randint(0, 3, size=sequences.shape[0])  # Placeholder for actual labels

    # 70:15:15 split (train, validation, test)
    split_1 = int(0.7 * len(sequences))
    split_2 = int(0.85 * len(sequences))
    X_train, X_val, X_test = (
        sequences[:split_1],
        sequences[split_1:split_2],
        sequences[split_2:],
    )
    y_train, y_val, y_test = labels[:split_1], labels[split_1:split_2], labels[split_2:]

    # Build Bidirectional LSTM model
    model = Sequential([
        Bidirectional(LSTM(64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2]))),
        Dropout(0.3),
        Bidirectional(LSTM(32, return_sequences=False)),
        Dense(32, activation="relu"),
        Dropout(0.2),
        Dense(3, activation="softmax")
    ])
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

    # Train model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        verbose=1
    )

    # Save training metrics
    history_df = pd.DataFrame(history.history)
    history_df.to_csv(os.path.join(output_dir, f"{patient}_training_metrics.csv"), index=False)

    # Evaluate on test data
    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=["DX", "REL", "REM"])
    confusion = confusion_matrix(y_test, y_pred)

    # Save evaluation metrics
    with open(os.path.join(output_dir, f"{patient}_evaluation_metrics.txt"), "w") as f:
        f.write(f"Accuracy: {accuracy}\n")
        f.write(f"Classification Report:\n{report}\n")
        f.write(f"Confusion Matrix:\n{confusion}\n")

    # Extract feature importance from LSTM weights
    lstm_weights = model.layers[0].get_weights()[0]  # Input weights of the first LSTM layer
    feature_importance = np.mean(np.abs(lstm_weights), axis=(0, 1))  # Average importance across gates

    # Rank features by importance
    feature_ranking = pd.DataFrame({
        "Gene": gene_names,
        "Importance": feature_importance
    }).sort_values(by="Importance", ascending=False)

    return feature_ranking

# Process one patient at a time
def process_patient(patient, files):
    print(f"Processing {patient}...")

    # Load DX, REL, REM data
    dx_file = os.path.join(processed_matrices_dir, files.get("DX"))
    rel_file = os.path.join(processed_matrices_dir, files.get("REL"))
    rem_file = os.path.join(processed_matrices_dir, files.get("REM"))

    dx_df = pd.read_csv(dx_file)
    rel_df = pd.read_csv(rel_file)
    rem_df = pd.read_csv(rem_file)

    # Extract genes and samples
    common_genes = set(dx_df["Gene"]).intersection(rel_df["Gene"]).intersection(rem_df["Gene"])
    dx_df = dx_df[dx_df["Gene"].isin(common_genes)].set_index("Gene")
    rel_df = rel_df[rel_df["Gene"].isin(common_genes)].set_index("Gene")
    rem_df = rem_df[rem_df["Gene"].isin(common_genes)].set_index("Gene")

    # Combine DX, REL, REM into sequences (samples x timepoints)
    sequences = np.stack([dx_df.mean(axis=1).values, rel_df.mean(axis=1).values, rem_df.mean(axis=1).values], axis=1)
    labels = np.array([0, 1, 2])  # DX=0, REL=1, REM=2

    # Train Bidirectional LSTM and extract feature importance
    feature_ranking = train_bilstm_and_extract_importance(sequences, labels, dx_df.index.tolist(), patient)

    # Save top 100 features
    top_100_features = feature_ranking.head(100)
    top_100_features.to_csv(os.path.join(output_dir, f"{patient}_top_100_features.csv"), index=False)

    print(f"Completed {patient}")

# Organize files by patient
file_groups = {}
for file in os.listdir(processed_matrices_dir):
    if not file.endswith("_processed_matrix.csv"):
        continue
    parts = file.split("_")
    patient, state = parts[1], parts[2]
    file_groups.setdefault(patient, {})[state] = file

# Run the analysis
for patient, files in file_groups.items():
    process_patient(patient, files)

print("Bidirectional LSTM feature importance analysis completed.")
# Out:
# Processing AML16...
# Epoch 1/50
# 1065/1065 [==============================] - 77s 55ms/step - loss: 1.0987 - accuracy: 0.3329 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 2/50
# 1065/1065 [==============================] - 46s 43ms/step - loss: 1.0989 - accuracy: 0.3360 - val_loss: 1.0989 - val_accuracy: 0.3328
# Epoch 3/50
# 1065/1065 [==============================] - 47s 44ms/step - loss: 1.0987 - accuracy: 0.3387 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 4/50
# 1065/1065 [==============================] - 43s 41ms/step - loss: 1.0986 - accuracy: 0.3378 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 5/50
# 1065/1065 [==============================] - 41s 38ms/step - loss: 1.0987 - accuracy: 0.3388 - val_loss: 1.0986 - val_accuracy: 0.3369
# Epoch 6/50
# 1065/1065 [==============================] - 36s 34ms/step - loss: 1.0988 - accuracy: 0.3374 - val_loss: 1.0990 - val_accuracy: 0.3331
# Epoch 7/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0986 - accuracy: 0.3379 - val_loss: 1.0987 - val_accuracy: 0.3333
# Epoch 8/50
# 1065/1065 [==============================] - 34s 31ms/step - loss: 1.0986 - accuracy: 0.3379 - val_loss: 1.0993 - val_accuracy: 0.3350
# Epoch 9/50
# 1065/1065 [==============================] - 35s 32ms/step - loss: 1.0987 - accuracy: 0.3383 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 10/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0986 - accuracy: 0.3366 - val_loss: 1.0987 - val_accuracy: 0.3331
# Epoch 11/50
# 1065/1065 [==============================] - 28s 27ms/step - loss: 1.0988 - accuracy: 0.3383 - val_loss: 1.0986 - val_accuracy: 0.3328
# Epoch 12/50
# 1065/1065 [==============================] - 32s 30ms/step - loss: 1.0986 - accuracy: 0.3369 - val_loss: 1.0989 - val_accuracy: 0.3328
# Epoch 13/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0986 - accuracy: 0.3399 - val_loss: 1.0990 - val_accuracy: 0.3331
# Epoch 14/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0988 - accuracy: 0.3388 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 15/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0985 - accuracy: 0.3381 - val_loss: 1.0988 - val_accuracy: 0.3328
# Epoch 16/50
# 1065/1065 [==============================] - 36s 34ms/step - loss: 1.0985 - accuracy: 0.3399 - val_loss: 1.0988 - val_accuracy: 0.3328
# Epoch 17/50
# 1065/1065 [==============================] - 35s 33ms/step - loss: 1.0985 - accuracy: 0.3382 - val_loss: 1.0996 - val_accuracy: 0.3331
# Epoch 18/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0986 - accuracy: 0.3380 - val_loss: 1.0989 - val_accuracy: 0.3328
# Epoch 19/50
# 1065/1065 [==============================] - 26s 25ms/step - loss: 1.0985 - accuracy: 0.3360 - val_loss: 1.0993 - val_accuracy: 0.3328
# Epoch 20/50
# 1065/1065 [==============================] - 31s 29ms/step - loss: 1.0984 - accuracy: 0.3392 - val_loss: 1.0990 - val_accuracy: 0.3328
# Epoch 21/50
# 1065/1065 [==============================] - 30s 29ms/step - loss: 1.0983 - accuracy: 0.3361 - val_loss: 1.0993 - val_accuracy: 0.3328
# Epoch 22/50
# 1065/1065 [==============================] - 31s 29ms/step - loss: 1.0985 - accuracy: 0.3396 - val_loss: 1.0988 - val_accuracy: 0.3333
# Epoch 23/50
# 1065/1065 [==============================] - 33s 31ms/step - loss: 1.0984 - accuracy: 0.3394 - val_loss: 1.0997 - val_accuracy: 0.3328
# Epoch 24/50
# 1065/1065 [==============================] - 32s 30ms/step - loss: 1.0984 - accuracy: 0.3382 - val_loss: 1.0991 - val_accuracy: 0.3333
# Epoch 25/50
# 1065/1065 [==============================] - 32s 30ms/step - loss: 1.0985 - accuracy: 0.3375 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 26/50
# 1065/1065 [==============================] - 26s 25ms/step - loss: 1.0984 - accuracy: 0.3400 - val_loss: 1.0990 - val_accuracy: 0.3328
# Epoch 27/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0984 - accuracy: 0.3399 - val_loss: 1.0989 - val_accuracy: 0.3333
# Epoch 28/50
# 1065/1065 [==============================] - 27s 25ms/step - loss: 1.0984 - accuracy: 0.3358 - val_loss: 1.1017 - val_accuracy: 0.3328
# Epoch 29/50
# 1065/1065 [==============================] - 29s 28ms/step - loss: 1.0984 - accuracy: 0.3403 - val_loss: 1.0989 - val_accuracy: 0.3366
# Epoch 30/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0984 - accuracy: 0.3335 - val_loss: 1.0991 - val_accuracy: 0.3331
# Epoch 31/50
# 1065/1065 [==============================] - 32s 30ms/step - loss: 1.0987 - accuracy: 0.3400 - val_loss: 1.0994 - val_accuracy: 0.3328
# Epoch 32/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0984 - accuracy: 0.3367 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 33/50
# 1065/1065 [==============================] - 24s 23ms/step - loss: 1.0984 - accuracy: 0.3382 - val_loss: 1.1006 - val_accuracy: 0.3328
# Epoch 34/50
# 1065/1065 [==============================] - 27s 25ms/step - loss: 1.0984 - accuracy: 0.3395 - val_loss: 1.1002 - val_accuracy: 0.3331
# Epoch 35/50
# 1065/1065 [==============================] - 25s 23ms/step - loss: 1.0984 - accuracy: 0.3400 - val_loss: 1.0988 - val_accuracy: 0.3331
# Epoch 36/50
# 1065/1065 [==============================] - 27s 25ms/step - loss: 1.0984 - accuracy: 0.3364 - val_loss: 1.0990 - val_accuracy: 0.3331
# Epoch 37/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0984 - accuracy: 0.3374 - val_loss: 1.0989 - val_accuracy: 0.3328
# Epoch 38/50
# 1065/1065 [==============================] - 34s 32ms/step - loss: 1.0983 - accuracy: 0.3358 - val_loss: 1.1044 - val_accuracy: 0.3331
# Epoch 39/50
# 1065/1065 [==============================] - 29s 28ms/step - loss: 1.0984 - accuracy: 0.3399 - val_loss: 1.1058 - val_accuracy: 0.3331
# Epoch 40/50
# 1065/1065 [==============================] - 30s 28ms/step - loss: 1.0986 - accuracy: 0.3398 - val_loss: 1.0991 - val_accuracy: 0.3333
# Epoch 41/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0985 - accuracy: 0.3400 - val_loss: 1.0988 - val_accuracy: 0.3333
# Epoch 42/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0984 - accuracy: 0.3398 - val_loss: 1.0991 - val_accuracy: 0.3331
# Epoch 43/50
# 1065/1065 [==============================] - 28s 27ms/step - loss: 1.0984 - accuracy: 0.3362 - val_loss: 1.0995 - val_accuracy: 0.3328
# Epoch 44/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0986 - accuracy: 0.3382 - val_loss: 1.0990 - val_accuracy: 0.3333
# Epoch 45/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0984 - accuracy: 0.3401 - val_loss: 1.0997 - val_accuracy: 0.3328
# Epoch 46/50
# 1065/1065 [==============================] - 29s 27ms/step - loss: 1.0984 - accuracy: 0.3356 - val_loss: 1.0986 - val_accuracy: 0.3333
# Epoch 47/50
# 1065/1065 [==============================] - 28s 26ms/step - loss: 1.0984 - accuracy: 0.3356 - val_loss: 1.0991 - val_accuracy: 0.3331
# Epoch 48/50
# 1065/1065 [==============================] - 28s 26ms/step - loss: 1.0983 - accuracy: 0.3400 - val_loss: 1.1013 - val_accuracy: 0.3328
# Epoch 49/50
# 1065/1065 [==============================] - 28s 27ms/step - loss: 1.0985 - accuracy: 0.3398 - val_loss: 1.1002 - val_accuracy: 0.3328
# Epoch 50/50
# 1065/1065 [==============================] - 28s 26ms/step - loss: 1.0985 - accuracy: 0.3370 - val_loss: 1.0996 - val_accuracy: 0.3328
# 115/115 [==============================] - 3s 11ms/step
# Completed AML16
# Processing AML6...
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/50
# 1016/1016 [==============================] - 43s 36ms/step - loss: 1.0990 - accuracy: 0.3332 - val_loss: 1.0989 - val_accuracy: 0.3322
# Epoch 2/50
# 1016/1016 [==============================] - 34s 33ms/step - loss: 1.0986 - accuracy: 0.3351 - val_loss: 1.0988 - val_accuracy: 0.3336
# Epoch 3/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3348 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 4/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0988 - accuracy: 0.3266 - val_loss: 1.0987 - val_accuracy: 0.3322
# Epoch 5/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3318 - val_loss: 1.0987 - val_accuracy: 0.3319
# Epoch 6/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3345 - val_loss: 1.0988 - val_accuracy: 0.3313
# Epoch 7/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3343 - val_loss: 1.0989 - val_accuracy: 0.3339
# Epoch 8/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0986 - val_accuracy: 0.3342
# Epoch 9/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3357 - val_loss: 1.0987 - val_accuracy: 0.3342
# Epoch 10/50
# 1016/1016 [==============================] - 34s 33ms/step - loss: 1.0986 - accuracy: 0.3301 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 11/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3364 - val_loss: 1.0987 - val_accuracy: 0.3348
# Epoch 12/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0987 - accuracy: 0.3319 - val_loss: 1.0987 - val_accuracy: 0.3316
# Epoch 13/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3339 - val_loss: 1.0987 - val_accuracy: 0.3316
# Epoch 14/50
# 1016/1016 [==============================] - 31s 31ms/step - loss: 1.0987 - accuracy: 0.3313 - val_loss: 1.0988 - val_accuracy: 0.3316
# Epoch 15/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0985 - accuracy: 0.3417 - val_loss: 1.0997 - val_accuracy: 0.3342
# Epoch 16/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0987 - accuracy: 0.3300 - val_loss: 1.0987 - val_accuracy: 0.3319
# Epoch 17/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0986 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3339
# Epoch 18/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0986 - accuracy: 0.3334 - val_loss: 1.0987 - val_accuracy: 0.3322
# Epoch 19/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0987 - accuracy: 0.3344 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 20/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3359 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 21/50
# 1016/1016 [==============================] - 33s 33ms/step - loss: 1.0985 - accuracy: 0.3391 - val_loss: 1.0988 - val_accuracy: 0.3339
# Epoch 22/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3362 - val_loss: 1.0987 - val_accuracy: 0.3325
# Epoch 23/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0986 - accuracy: 0.3348 - val_loss: 1.0988 - val_accuracy: 0.3322
# Epoch 24/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0985 - accuracy: 0.3316 - val_loss: 1.0989 - val_accuracy: 0.3325
# Epoch 25/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0986 - accuracy: 0.3298 - val_loss: 1.0989 - val_accuracy: 0.3319
# Epoch 26/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3350 - val_loss: 1.0988 - val_accuracy: 0.3322
# Epoch 27/50
# 1016/1016 [==============================] - 32s 31ms/step - loss: 1.0986 - accuracy: 0.3358 - val_loss: 1.0987 - val_accuracy: 0.3325
# Epoch 28/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0985 - accuracy: 0.3372 - val_loss: 1.0989 - val_accuracy: 0.3342
# Epoch 29/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0985 - accuracy: 0.3366 - val_loss: 1.0987 - val_accuracy: 0.3319
# Epoch 30/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3350 - val_loss: 1.0988 - val_accuracy: 0.3322
# Epoch 31/50
# 1016/1016 [==============================] - 33s 33ms/step - loss: 1.0986 - accuracy: 0.3402 - val_loss: 1.0988 - val_accuracy: 0.3345
# Epoch 32/50
# 1016/1016 [==============================] - 32s 32ms/step - loss: 1.0987 - accuracy: 0.3338 - val_loss: 1.0986 - val_accuracy: 0.3325
# Epoch 33/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0988 - val_accuracy: 0.3316
# Epoch 34/50
# 1016/1016 [==============================] - 33s 33ms/step - loss: 1.0985 - accuracy: 0.3376 - val_loss: 1.0987 - val_accuracy: 0.3322
# Epoch 35/50
# 1016/1016 [==============================] - 33s 32ms/step - loss: 1.0986 - accuracy: 0.3312 - val_loss: 1.0988 - val_accuracy: 0.3322
# Epoch 36/50
# 1016/1016 [==============================] - 33s 33ms/step - loss: 1.0985 - accuracy: 0.3353 - val_loss: 1.0987 - val_accuracy: 0.3339
# Epoch 37/50
# 1016/1016 [==============================] - 34s 33ms/step - loss: 1.0985 - accuracy: 0.3313 - val_loss: 1.0989 - val_accuracy: 0.3319
# Epoch 38/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0986 - accuracy: 0.3335 - val_loss: 1.0987 - val_accuracy: 0.3325
# Epoch 39/50
# 1016/1016 [==============================] - 35s 35ms/step - loss: 1.0984 - accuracy: 0.3343 - val_loss: 1.0989 - val_accuracy: 0.3339
# Epoch 40/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0986 - accuracy: 0.3370 - val_loss: 1.0989 - val_accuracy: 0.3342
# Epoch 41/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0987 - accuracy: 0.3353 - val_loss: 1.0989 - val_accuracy: 0.3316
# Epoch 42/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0986 - accuracy: 0.3347 - val_loss: 1.0990 - val_accuracy: 0.3316
# Epoch 43/50
# 1016/1016 [==============================] - 35s 35ms/step - loss: 1.0986 - accuracy: 0.3342 - val_loss: 1.0989 - val_accuracy: 0.3319
# Epoch 44/50
# 1016/1016 [==============================] - 34s 34ms/step - loss: 1.0985 - accuracy: 0.3338 - val_loss: 1.0990 - val_accuracy: 0.3319
# Epoch 45/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0985 - accuracy: 0.3334 - val_loss: 1.0989 - val_accuracy: 0.3319
# Epoch 46/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0985 - accuracy: 0.3338 - val_loss: 1.0988 - val_accuracy: 0.3316
# Epoch 47/50
# 1016/1016 [==============================] - 35s 34ms/step - loss: 1.0986 - accuracy: 0.3365 - val_loss: 1.0987 - val_accuracy: 0.3342
# Epoch 48/50
# 1016/1016 [==============================] - 35s 35ms/step - loss: 1.0985 - accuracy: 0.3388 - val_loss: 1.0988 - val_accuracy: 0.3342
# Epoch 49/50
# 1016/1016 [==============================] - 36s 35ms/step - loss: 1.0985 - accuracy: 0.3317 - val_loss: 1.0988 - val_accuracy: 0.3322
# Epoch 50/50
# 1016/1016 [==============================] - 33s 33ms/step - loss: 1.0985 - accuracy: 0.3327 - val_loss: 1.0991 - val_accuracy: 0.3316
# 109/109 [==============================] - 3s 12ms/step
# Completed AML6
# Processing AML2...
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/50
# 1034/1034 [==============================] - 40s 32ms/step - loss: 1.0988 - accuracy: 0.3373 - val_loss: 1.0989 - val_accuracy: 0.3282
# Epoch 2/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0990 - accuracy: 0.3335 - val_loss: 1.0989 - val_accuracy: 0.3276
# Epoch 3/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0988 - accuracy: 0.3256 - val_loss: 1.0986 - val_accuracy: 0.3414
# Epoch 4/50
# 1034/1034 [==============================] - 31s 30ms/step - loss: 1.0987 - accuracy: 0.3378 - val_loss: 1.0988 - val_accuracy: 0.3304
# Epoch 5/50
# 1034/1034 [==============================] - 32s 31ms/step - loss: 1.0987 - accuracy: 0.3348 - val_loss: 1.0986 - val_accuracy: 0.3411
# Epoch 6/50
# 1034/1034 [==============================] - 32s 31ms/step - loss: 1.0988 - accuracy: 0.3283 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 7/50
# 1034/1034 [==============================] - 31s 30ms/step - loss: 1.0987 - accuracy: 0.3341 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 8/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3336 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 9/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3361 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 10/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3250 - val_loss: 1.0986 - val_accuracy: 0.3304
# Epoch 11/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3304 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 12/50
# 1034/1034 [==============================] - 31s 30ms/step - loss: 1.0987 - accuracy: 0.3382 - val_loss: 1.0989 - val_accuracy: 0.3279
# Epoch 13/50
# 1034/1034 [==============================] - 35s 34ms/step - loss: 1.0987 - accuracy: 0.3322 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 14/50
# 1034/1034 [==============================] - 35s 34ms/step - loss: 1.0988 - accuracy: 0.3272 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 15/50
# 1034/1034 [==============================] - 34s 33ms/step - loss: 1.0989 - accuracy: 0.3387 - val_loss: 1.0989 - val_accuracy: 0.3279
# Epoch 16/50
# 1034/1034 [==============================] - 32s 31ms/step - loss: 1.0988 - accuracy: 0.3355 - val_loss: 1.0989 - val_accuracy: 0.3273
# Epoch 17/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3270 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 18/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0987 - accuracy: 0.3330 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 19/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0988 - accuracy: 0.3330 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 20/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0988 - accuracy: 0.3352 - val_loss: 1.0989 - val_accuracy: 0.3279
# Epoch 21/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0987 - accuracy: 0.3327 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 22/50
# 1034/1034 [==============================] - 28s 27ms/step - loss: 1.0987 - accuracy: 0.3335 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 23/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3344 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 24/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0988 - accuracy: 0.3321 - val_loss: 1.0986 - val_accuracy: 0.3282
# Epoch 25/50
# 1034/1034 [==============================] - 31s 30ms/step - loss: 1.0987 - accuracy: 0.3332 - val_loss: 1.0987 - val_accuracy: 0.3304
# Epoch 26/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3318 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 27/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0988 - accuracy: 0.3318 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 28/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0987 - accuracy: 0.3334 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 29/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0987 - accuracy: 0.3324 - val_loss: 1.0986 - val_accuracy: 0.3279
# Epoch 30/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0987 - accuracy: 0.3339 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 31/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3286 - val_loss: 1.0986 - val_accuracy: 0.3279
# Epoch 32/50
# 1034/1034 [==============================] - 29s 28ms/step - loss: 1.0988 - accuracy: 0.3295 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 33/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3324 - val_loss: 1.0989 - val_accuracy: 0.3279
# Epoch 34/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3335 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 35/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3374 - val_loss: 1.0987 - val_accuracy: 0.3304
# Epoch 36/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3362 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 37/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3359 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 38/50
# 1034/1034 [==============================] - 30s 29ms/step - loss: 1.0987 - accuracy: 0.3333 - val_loss: 1.0989 - val_accuracy: 0.3304
# Epoch 39/50
# 1034/1034 [==============================] - 28s 27ms/step - loss: 1.0987 - accuracy: 0.3341 - val_loss: 1.0990 - val_accuracy: 0.3279
# Epoch 40/50
# 1034/1034 [==============================] - 38s 37ms/step - loss: 1.0988 - accuracy: 0.3319 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 41/50
# 1034/1034 [==============================] - 40s 39ms/step - loss: 1.0988 - accuracy: 0.3336 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 42/50
# 1034/1034 [==============================] - 40s 39ms/step - loss: 1.0987 - accuracy: 0.3336 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 43/50
# 1034/1034 [==============================] - 41s 40ms/step - loss: 1.0987 - accuracy: 0.3321 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 44/50
# 1034/1034 [==============================] - 41s 40ms/step - loss: 1.0987 - accuracy: 0.3314 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 45/50
# 1034/1034 [==============================] - 39s 38ms/step - loss: 1.0988 - accuracy: 0.3328 - val_loss: 1.0987 - val_accuracy: 0.3304
# Epoch 46/50
# 1034/1034 [==============================] - 41s 40ms/step - loss: 1.0987 - accuracy: 0.3361 - val_loss: 1.0986 - val_accuracy: 0.3417
# Epoch 47/50
# 1034/1034 [==============================] - 40s 38ms/step - loss: 1.0987 - accuracy: 0.3311 - val_loss: 1.0985 - val_accuracy: 0.3417
# Epoch 48/50
# 1034/1034 [==============================] - 38s 37ms/step - loss: 1.0988 - accuracy: 0.3293 - val_loss: 1.0987 - val_accuracy: 0.3279
# Epoch 49/50
# 1034/1034 [==============================] - 40s 39ms/step - loss: 1.0987 - accuracy: 0.3319 - val_loss: 1.0988 - val_accuracy: 0.3279
# Epoch 50/50
# 1034/1034 [==============================] - 40s 39ms/step - loss: 1.0987 - accuracy: 0.3286 - val_loss: 1.0986 - val_accuracy: 0.3417
# 111/111 [==============================] - 3s 11ms/step
# Completed AML2
# Processing AML15...
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/50
# 1008/1008 [==============================] - 46s 38ms/step - loss: 1.0987 - accuracy: 0.3343 - val_loss: 1.0982 - val_accuracy: 0.3473
# Epoch 2/50
# 1008/1008 [==============================] - 35s 34ms/step - loss: 1.0990 - accuracy: 0.3335 - val_loss: 1.0987 - val_accuracy: 0.3184
# Epoch 3/50
# 1008/1008 [==============================] - 35s 35ms/step - loss: 1.0987 - accuracy: 0.3303 - val_loss: 1.0991 - val_accuracy: 0.3184
# Epoch 4/50
# 1008/1008 [==============================] - 34s 34ms/step - loss: 1.0989 - accuracy: 0.3312 - val_loss: 1.0986 - val_accuracy: 0.3482
# Epoch 5/50
# 1008/1008 [==============================] - 35s 35ms/step - loss: 1.0988 - accuracy: 0.3304 - val_loss: 1.0988 - val_accuracy: 0.3184
# Epoch 6/50
# 1008/1008 [==============================] - 34s 34ms/step - loss: 1.0988 - accuracy: 0.3320 - val_loss: 1.0988 - val_accuracy: 0.3482
# Epoch 7/50
# 1008/1008 [==============================] - 34s 34ms/step - loss: 1.0987 - accuracy: 0.3288 - val_loss: 1.0990 - val_accuracy: 0.3184
# Epoch 8/50
#  180/1008 [====>.........................] - ETA: 27s - loss: 1.0989 - accuracy: 0.3431

# %%
##Transformer

# %%
import os
import numpy as np
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, MultiHeadAttention, LayerNormalization, Dropout, GlobalAveragePooling1D
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
output_dir = "results/transformer_analysis"
os.makedirs(output_dir, exist_ok=True)

# Transformer Model Definition
def build_transformer_model(input_shape, num_heads, num_classes):
    inputs = Input(shape=input_shape)

    # Multi-Head Attention Layer
    attention_layer = MultiHeadAttention(num_heads=num_heads, key_dim=input_shape[-1])
    attention_output = attention_layer(inputs, inputs)
    attention_output = LayerNormalization(epsilon=1e-6)(attention_output + inputs)

    # Feedforward Network
    ffn_output = Dense(64, activation="relu")(attention_output)
    ffn_output = Dense(input_shape[-1], activation="linear")(ffn_output)
    ffn_output = LayerNormalization(epsilon=1e-6)(ffn_output + attention_output)

    # Global Average Pooling
    pooled_output = GlobalAveragePooling1D()(ffn_output)

    # Final Classification Layer
    outputs = Dense(num_classes, activation="softmax")(pooled_output)

    return Model(inputs, outputs), attention_layer

# Train Transformer and Extract Feature Importance
def train_transformer_and_extract_importance(sequences, labels, gene_names, patient):
    # Normalize data
    scaler = MinMaxScaler()
    sequences = scaler.fit_transform(sequences)

    # Reshape to (samples, timesteps, features)
    sequences = sequences.reshape((sequences.shape[0], sequences.shape[1], 1))

    # Generate dummy labels matching samples (one per row/gene)
    labels = np.random.randint(0, 3, size=sequences.shape[0])  # Placeholder for actual labels

    # 70:15:15 split (train, validation, test)
    split_1 = int(0.7 * len(sequences))
    split_2 = int(0.85 * len(sequences))
    X_train, X_val, X_test = (
        sequences[:split_1],
        sequences[split_1:split_2],
        sequences[split_2:],
    )
    y_train, y_val, y_test = labels[:split_1], labels[split_1:split_2], labels[split_2:]

    # Build Transformer model
    model, attention_layer = build_transformer_model(
        input_shape=(X_train.shape[1], X_train.shape[2]), num_heads=4, num_classes=3
    )
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

    # Train model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50,
        batch_size=16,
        verbose=1
    )

    # Save training metrics
    history_df = pd.DataFrame(history.history)
    history_df.to_csv(os.path.join(output_dir, f"{patient}_training_metrics.csv"), index=False)

    # Evaluate on test data
    y_pred = np.argmax(model.predict(X_test), axis=1)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=["DX", "REL", "REM"])
    confusion = confusion_matrix(y_test, y_pred)

    # Save evaluation metrics
    with open(os.path.join(output_dir, f"{patient}_evaluation_metrics.txt"), "w") as f:
        f.write(f"Accuracy: {accuracy}\n")
        f.write(f"Classification Report:\n{report}\n")
        f.write(f"Confusion Matrix:\n{confusion}\n")

    # Manually extract attention scores using the attention layer
    attention_model = Model(inputs=model.input, outputs=attention_layer.call(model.input, model.input))
    attention_weights = attention_model.predict(sequences)

    # Aggregate attention scores across all heads and timesteps
    feature_importance = np.mean(np.abs(attention_weights), axis=(1, 2))  # Average across time and heads

    # Rank features by importance
    feature_ranking = pd.DataFrame({
        "Gene": gene_names,
        "Importance": feature_importance
    }).sort_values(by="Importance", ascending=False)

    return feature_ranking

# Process one patient at a time
def process_patient(patient, files):
    print(f"Processing {patient}...")

    # Load DX, REL, REM data
    dx_file = os.path.join(processed_matrices_dir, files.get("DX"))
    rel_file = os.path.join(processed_matrices_dir, files.get("REL"))
    rem_file = os.path.join(processed_matrices_dir, files.get("REM"))

    dx_df = pd.read_csv(dx_file)
    rel_df = pd.read_csv(rel_file)
    rem_df = pd.read_csv(rem_file)

    # Extract genes and samples
    common_genes = set(dx_df["Gene"]).intersection(rel_df["Gene"]).intersection(rem_df["Gene"])
    dx_df = dx_df[dx_df["Gene"].isin(common_genes)].set_index("Gene")
    rel_df = rel_df[rel_df["Gene"].isin(common_genes)].set_index("Gene")
    rem_df = rem_df[rem_df["Gene"].isin(common_genes)].set_index("Gene")

    # Combine DX, REL, REM into sequences (samples x timepoints)
    sequences = np.stack([dx_df.mean(axis=1).values, rel_df.mean(axis=1).values, rem_df.mean(axis=1).values], axis=1)
    labels = np.array([0, 1, 2])  # DX=0, REL=1, REM=2

    # Train Transformer and extract feature importance
    feature_ranking = train_transformer_and_extract_importance(sequences, labels, dx_df.index.tolist(), patient)

    # Save top 100 features
    top_100_features = feature_ranking.head(100)
    top_100_features.to_csv(os.path.join(output_dir, f"{patient}_top_100_features.csv"), index=False)

    print(f"Completed {patient}")

# Organize files by patient
file_groups = {}
for file in os.listdir(processed_matrices_dir):
    if not file.endswith("_processed_matrix.csv"):
        continue
    parts = file.split("_")
    patient, state = parts[1], parts[2]
    file_groups.setdefault(patient, {})[state] = file

# Run the analysis
for patient, files in file_groups.items():
    process_patient(patient, files)

print("Transformer feature importance analysis completed.")

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.18.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\uabic\appdata\roaming\python\python39\site-packages
# Requires: tensorflow-intel
# Required-by: tf_keras
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\uabic\anaconda3\lib\site-packages)

# %%
###DEG statistical + BDM

# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
from pybdm import BDM

# Initialize BDM object
bdm = BDM(ndim=2)

# Define directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
output_dir = "results/statistical_deg_bdm"
os.makedirs(output_dir, exist_ok=True)

# Helper: Compute Differential Expression
def compute_deg(dx_df, rel_df, rem_df, logfc_threshold=1.0, pval_threshold=0.05):
    epsilon = 1e-9  # Small constant to avoid log(0)
    genes = dx_df.index
    deg_results = []

    for gene in genes:
        dx_vals = dx_df.loc[gene].values
        rel_vals = rel_df.loc[gene].values
        rem_vals = rem_df.loc[gene].values

        # Compute log fold changes
        logfc_dx_rel = np.log2(np.mean(rel_vals) + epsilon) - np.log2(np.mean(dx_vals) + epsilon)
        logfc_dx_rem = np.log2(np.mean(rem_vals) + epsilon) - np.log2(np.mean(dx_vals) + epsilon)
        logfc_rel_rem = np.log2(np.mean(rem_vals) + epsilon) - np.log2(np.mean(rel_vals) + epsilon)

        # Perform t-tests
        pval_dx_rel = ttest_ind(dx_vals, rel_vals, equal_var=False).pvalue
        pval_dx_rem = ttest_ind(dx_vals, rem_vals, equal_var=False).pvalue
        pval_rel_rem = ttest_ind(rel_vals, rem_vals, equal_var=False).pvalue

        deg_results.append({
            "Gene": gene,
            "LogFC_DX_REL": logfc_dx_rel,
            "LogFC_DX_REM": logfc_dx_rem,
            "LogFC_REL_REM": logfc_rel_rem,
            "Pval_DX_REL": pval_dx_rel,
            "Pval_DX_REM": pval_dx_rem,
            "Pval_REL_REM": pval_rel_rem
        })

    # Create DEG DataFrame
    deg_df = pd.DataFrame(deg_results)

    # Adjust p-values using Benjamini-Hochberg correction
    deg_df["Adj_Pval_DX_REL"] = multipletests(deg_df["Pval_DX_REL"], method="fdr_bh")[1]
    deg_df["Adj_Pval_DX_REM"] = multipletests(deg_df["Pval_DX_REM"], method="fdr_bh")[1]
    deg_df["Adj_Pval_REL_REM"] = multipletests(deg_df["Pval_REL_REM"], method="fdr_bh")[1]

    # Filter significant DEGs
    deg_df = deg_df[
        (deg_df["Adj_Pval_DX_REL"] < pval_threshold) |
        (deg_df["Adj_Pval_DX_REM"] < pval_threshold) | 
        (deg_df["Adj_Pval_REL_REM"] < pval_threshold)
    ]

    # Select top 100 DEGs by absolute logFC
    deg_df["Abs_LogFC"] = deg_df[["LogFC_DX_REL", "LogFC_DX_REM", "LogFC_REL_REM"]].abs().max(axis=1)
    top_100_degs = deg_df.nlargest(100, "Abs_LogFC")

    # Add up/downregulated classification
    top_100_degs["Regulation"] = top_100_degs.apply(
        lambda row: "Upregulated" if row["LogFC_DX_REL"] > 0 else "Downregulated", axis=1
    )

    return top_100_degs

# Updated Helper: Compute BDM Perturbation Analysis
def compute_bdm(deg_df, dx_df, rel_df, rem_df):
    # Align columns (samples) across all DataFrames
    common_samples = dx_df.columns.intersection(rel_df.columns).intersection(rem_df.columns)
    dx_df = dx_df[common_samples]
    rel_df = rel_df[common_samples]
    rem_df = rem_df[common_samples]
    
    bdm_results = []
    for gene in deg_df["Gene"]:
        dx_vals = dx_df.loc[gene].values
        rel_vals = rel_df.loc[gene].values
        rem_vals = rem_df.loc[gene].values

        # Ensure dimensions match
        if len(dx_vals) != len(rel_vals) or len(dx_vals) != len(rem_vals):
            print(f"Skipping gene {gene} due to mismatched dimensions.")
            continue

        # Compute binary matrices
        binary_dx = (dx_vals > np.median(dx_vals)).astype(int)
        binary_rel = (rel_vals > np.median(rel_vals)).astype(int)
        binary_rem = (rem_vals > np.median(rem_vals)).astype(int)

        # Compute BDM for state transitions
        try:
            bdm_dx_rel = bdm.bdm(np.vstack([binary_dx, binary_rel]))
            bdm_rel_rem = bdm.bdm(np.vstack([binary_rel, binary_rem]))
            bdm_dx_rem = bdm.bdm(np.vstack([binary_dx, binary_rem]))

            bdm_results.append({
                "Gene": gene,
                "BDM_DX_REL": bdm_dx_rel,
                "BDM_REL_REM": bdm_rel_rem,
                "BDM_DX_REM": bdm_dx_rem
            })
        except ValueError as e:
            print(f"Error processing gene {gene}: {e}")
            continue

    return pd.DataFrame(bdm_results)

# Rest of the workflow remains the same.
# Main Workflow
def process_patient(patient, files):
    print(f"Processing {patient}...")

    dx_file = os.path.join(processed_matrices_dir, files["DX"])
    rel_file = os.path.join(processed_matrices_dir, files["REL"])
    rem_file = os.path.join(processed_matrices_dir, files["REM"])

    # Load the data
    dx_df = pd.read_csv(dx_file).set_index("Gene")
    rel_df = pd.read_csv(rel_file).set_index("Gene")
    rem_df = pd.read_csv(rem_file).set_index("Gene")

    # Filter out all-zero genes
    dx_df = dx_df[(dx_df.T != 0).any()]
    rel_df = rel_df[(rel_df.T != 0).any()]
    rem_df = rem_df[(rem_df.T != 0).any()]

    # Align indices of all DataFrames (genes)
    common_genes = dx_df.index.intersection(rel_df.index).intersection(rem_df.index)
    dx_df = dx_df.loc[common_genes]
    rel_df = rel_df.loc[common_genes]
    rem_df = rem_df.loc[common_genes]

    # Compute DEGs
    top_100_degs = compute_deg(dx_df, rel_df, rem_df)
    top_100_degs.to_csv(os.path.join(output_dir, f"{patient}_top_100_degs.csv"), index=False)

    # Compute BDM values
    bdm_results = compute_bdm(top_100_degs, dx_df, rel_df, rem_df)
    bdm_results.to_csv(os.path.join(output_dir, f"{patient}_bdm_results.csv"), index=False)

# Organize files by patient
file_groups = {}
for file in os.listdir(processed_matrices_dir):
    if not file.endswith("_processed_matrix.csv"):
        continue
    parts = file.split("_")
    patient, state = parts[1], parts[2]
    file_groups.setdefault(patient, {})[state] = file

# Run the analysis
for patient, files in file_groups.items():
    process_patient(patient, files)

print("Statistical DEG and BDM analysis completed.")
# Out:
# Processing AML16...
# Error processing gene PRTN3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD24: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPB41L3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BIRC7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene POU4F1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ELANE: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C15orf48: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAV1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OLR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPBP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MPO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NPW: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AFAP1-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPCAM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD19: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRSS2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C2CD4B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYTL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CA4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EDIL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRAME: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DNTT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGLL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HDC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AHSP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene INPP5J: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DLL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAVIN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VPREB3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPTA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GYPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPIRE1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GATM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NRN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTCRA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SHTN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00958: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL031710.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene WFDC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene THSD7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTH2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene WIPF3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD300E: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MAMDC2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene P2RY6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC026904.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VASN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PID1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYP27A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBP7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KCNC3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PNMA6A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CDC20: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EHD2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GGT5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGHA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TUSC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OSBPL1A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HPGDS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CPVL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCDC26: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITPKA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KRT17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NKAIN4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SRC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GSTM5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TGFBI: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM20C: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MARCO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CGREF1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRSS57: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM81A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LARGE1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MEG3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL356275.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EVPL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KHDRBS3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DOC2B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCNA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC01436: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC01268: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FPR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C1QA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PKP2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMKR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC068580.4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRRT4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FGFR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C1QTNF4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RAB7B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TMEM236: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SCN2A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KCNK12: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADAMTS3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPTLC3: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML6...
# Error processing gene HBA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ALAS2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AHSP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GYPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HEMGN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MYO6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene G0S2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPAG6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MYL4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC4A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCGR2A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RHAG: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM178B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VCAN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CES1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBG2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LAMB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC10A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TSPO2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A12: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MSLN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C5AR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGHA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMIM25: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPTA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRSS3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL513128.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00379: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLBD1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SOX6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SERPINA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KCNH2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRSS21: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AGR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TMEM136: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MAFB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene F5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GNG11: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLF1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SIRPB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FPR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LAMC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ENHO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC14A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MYCNOS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KRT1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FOLR3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM198B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNASE1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KEL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TAL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GPC4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PKLR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CDC42BPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD300E: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGFBP2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COL5A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAMSAP3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RHD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CR1L: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBP7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SCT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LRP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPTB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TPSAB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VPREB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGER1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PCAT18: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TGFBI: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYBB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF703: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LIN7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene A4GALT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC6A9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GOLGA8M: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RIPOR3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLC3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LARP6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC6A8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LRRK2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SIGLEC9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CRYGD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene YPEL4: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML2...
# Error processing gene PLBD1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC245128.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SERPINB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MINDY4B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DNTT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SERPINA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A12: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TLR8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DLX5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MARCO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VCAN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLF4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MAFB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADAMDEC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMIM25: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBG2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCDC144NL-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene G0S2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CES1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MYZAP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C5AR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCAR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL391807.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC105411.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C9orf47: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL31RA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MME: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBP7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNF182: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SORT1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBZ: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IER3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HEPACAM2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FFAR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SEMA3C: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KCNK10: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OLR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CRISPLD2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00570: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FPR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC15A3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ANGPT1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYGB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AQP9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYYR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCGR3A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LRRK2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPHB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGLC3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADAMTS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DLX6-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITLN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC103876.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF730: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LRP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC020656.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCDC148: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GIPC2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DEFA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNASE4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGDR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EGR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene QPCT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BATF3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MTMR11: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VAT1L: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FOSB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DOCK1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COL14A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SHTN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPP1R14A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMPD3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ART4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADRB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL138900.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMPDL3A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM198B-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD300E: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EIF4E3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CACNB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAVIN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene YPEL4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC8A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GALNT5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CDS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KIF5A: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML15...
# Error processing gene IL5RA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TCN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRAME: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene POU4F1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPB41L3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC22A15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TBX1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ENHO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PF4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NEGR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC10A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SECTM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RUNX1T1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL1RN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ALDH1A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00958: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLOD2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A12: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCND1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGLL5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD300E: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL031710.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NECAB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SERPINB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MME: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DLL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAVIN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM198B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPINK2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAV1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPBP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C15orf48: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GLT1D1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AQP9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CDC42BPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SDS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC111000.4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene WFDC2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MS4A2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXB3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HHIP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HMGA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD1D: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARPP21: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF385D: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00535: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MEIS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL450311.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC245128.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MYO18B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL009031.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD300LB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SDC2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SCT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DPPA4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RIN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYP27A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLITRK4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MPEG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KRT17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD86: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPESP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HNMT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TPSB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ALDH2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CPED1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL591848.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PCBP3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LMO1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TPSAB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC8A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CPVL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC125603.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MAFB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC005838.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM20C: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITLN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM178B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TGFBI: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC092490.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC104389.5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene APOBEC3A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD19: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA10: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF711: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBM47: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLBD1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CHRM3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HLF: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPINK4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BEX3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VSTM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KCNK17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NDN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COL9A3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CSRP2: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML7...
# Error processing gene CXCL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FOXC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EMX2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PROK2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXADR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NIPAL4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LIF: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITGB8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPP1R27: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL078459.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCDC74A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PXDC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL11: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MPO: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL157895.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EBF1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LGMN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OVCH1-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL590226.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MECOM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C15orf48: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BAALC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCRL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPAG6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNF144B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TRPM4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CES1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CAVIN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF385D: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ZNF595: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL022323.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AP000695.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLEKHN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC098484.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AK5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADAMTS4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VWDE: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC004540.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NALT1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene WNT11: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AP001189.5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EXPH5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITPK1-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene STOML1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC005363.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC104984.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DNAI2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC011476.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COX6B2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC007064.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COL19A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PNOC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PAX5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AP002761.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLLN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPFIA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC4A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CTSG: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LYZ: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TYROBP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DACH1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCR5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100P: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HMBS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene COL24A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLHL23: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AMOTL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene A4GALT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HEMGN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GYPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ISG15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCER1G: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene APOC2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CSF1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CHRM3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LIN7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HIST3H2A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MS4A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IFITM3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KYNU: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOTAIRM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene QPCT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GYPB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00309: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CTSB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DAPK1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC025580.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ALDH1A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CYP51A1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IRF7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC25A39: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AXL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC7A: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML8...
# Error processing gene SPINK1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SERPINB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GPNMB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITGA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LRP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene THBS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OLR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TBR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RAB31: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KRT17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL10: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MARCKS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LGMN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene THBD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MCEMP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MS4A7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene S100A12: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TREM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARL14EPL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RETN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HIST3H2A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene APP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MNDA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FOXC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRAME: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPB41L3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PROC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL16: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BCAT1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CHST15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DAB2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC002456.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MSLN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGES: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RIN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SMIM25: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene THSD7A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC008568.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CXCL8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MAFB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NIPAL4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD109: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene JAKMIP2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EGR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LIF: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MTSS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VCAN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene U62317.5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SPINK2: Computed BDM is 0, dataset may have incorrect dimensions
# ...
# Error processing gene HSPA1B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IFNB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBP7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AVP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ANGPT2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GXYLT2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGES: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PCSK1N: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HCAR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DEFA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGKC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ITLN1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FHDC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC130456.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VPREB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VCAM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DNTT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CRIP2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CHST15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HSPA6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL513217.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TMEM163: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CTHRC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MMP15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PHOSPHO1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCGR2B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GALNT14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ATP6V0D2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BAALC-AS2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LILRA6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNF182: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NNMT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADGRL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC010173.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC010329.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GPR162: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLEC10A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC100835.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EDIL3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC123912.4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene APOBEC3A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HIST1H2AJ: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TNXB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FCAR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC22A15: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBZ: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TSPAN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene STOML3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC012150.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SETBP1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC020911.2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGDR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CDC42BPA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC00570: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RTL8C: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGFBP3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARHGAP42: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AURKC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC6A8: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MSR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene UGT3A2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AKR1C2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC104170.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KLRC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AP000894.4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HBM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCL7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AMOTL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SEL1L2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MEGF11: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL592182.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLEK2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC024267.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NCAM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ERRFI1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL157935.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HSPA4L: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TSPO2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC4A1: Computed BDM is 0, dataset may have incorrect dimensions
# Processing AML24...
# Error processing gene RPS4Y1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EIF1AY: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DDX3Y: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGHG4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MRC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ENPP2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HRK: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGHG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC25A21: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PKLR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PKIB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PF4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KIAA1217: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PPBP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VPREB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CFAP73: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGLL5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXA4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TSPAN2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LCT: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C1QC: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SLC9A3R2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AL592430.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PTGES: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TBC1D16: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IL2RA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SELPLG: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HAL: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GGT5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene UTS2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NKX2-3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MARC1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DEGS2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DTNA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene OLFML2A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene FAM81B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ARTN: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene TRBVB: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene METTL7B: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ADGRA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VLDLR: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HPD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RAB3IL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CRYGD: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MGP: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VWA1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene UPK3A: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC074327.1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene IGHG3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ROR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MIR503HG: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CLDN10: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD24: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CCL2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RASSF4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RNASE6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SNAI3-AS1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AC245128.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NOV: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LAMP5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LDLRAD2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC01336: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HOXB-AS3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene EPCAM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene C5AR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KRT17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CRYM: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRTN3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ACTA2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene KIF17: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LYZ: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NRG4: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LCN6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRICKLE1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NFIA: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene UTF1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DHRS9: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LINC02147: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene DTX1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RBPMS: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene RPS6KL1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NEGR1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HCAR2: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene NECAB1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene MIR4458HG: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene SASH1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PRSS21: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PHLDA3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD1C: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene ECM1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene LAMA5: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BEND6: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD14: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene HTR7: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene BLK: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene CD180: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene GOLGA8M: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene PLEKHG1: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene AP000547.3: Computed BDM is 0, dataset may have incorrect dimensions
# Error processing gene VPREB3: Computed BDM is 0, dataset may have incorrect dimensions
# Statistical DEG and BDM analysis completed.

# %%
##BDM analysis on identified DEGs

# %%
import os
import pandas as pd
import numpy as np
from pybdm import BDM
from scipy.stats import spearmanr

# Initialize BDM object
bdm = BDM(ndim=2)

# Define directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
top_degs_dir = "results/statistical_deg_bdm"
bdm_results_dir = "results/bdm_analysis"
os.makedirs(bdm_results_dir, exist_ok=True)

# Thresholds for binarization
thresholds = [0.1, 0.5]

# Helper: Compute Spearman adjacency matrix
def compute_spearman_adjacency(data):
    adjacency = np.zeros((data.shape[0], data.shape[0]))
    for i in range(data.shape[0]):
        for j in range(i + 1, data.shape[0]):  # Avoid redundant computation
            corr, _ = spearmanr(data[i, :], data[j, :])
            adjacency[i, j] = corr
            adjacency[j, i] = corr  # Symmetric matrix
    return adjacency

# Helper: Perform BDM Perturbation Analysis
def bdm_analysis(matrix, threshold):
    binary_matrix = (matrix > threshold).astype(int)
    original_bdm = bdm.bdm(binary_matrix)

    # Node perturbation (set each node to 0)
    perturbed_bdm_values = []
    for i in range(binary_matrix.shape[0]):
        perturbed_matrix = binary_matrix.copy()
        perturbed_matrix[i, :] = 0
        perturbed_matrix[:, i] = 0
        perturbed_bdm_values.append(original_bdm - bdm.bdm(perturbed_matrix))

    return original_bdm, perturbed_bdm_values

# Process each patient's DEGs and compute BDM
for patient_file in os.listdir(top_degs_dir):
    if not patient_file.endswith("_top_100_degs.csv"):
        continue

    patient_name = patient_file.split("_top_100_degs.csv")[0]
    print(f"Processing patient: {patient_name}")

    # Create a directory for the patient
    patient_bdm_dir = os.path.join(bdm_results_dir, patient_name)
    os.makedirs(patient_bdm_dir, exist_ok=True)

    # Load top 100 DEGs
    top_degs = pd.read_csv(os.path.join(top_degs_dir, patient_file))["Gene"].values

    # Load DX, REL, and REM data
    try:
        dx_file = next(f for f in os.listdir(processed_matrices_dir) if f"{patient_name}_DX" in f)
        rel_file = next(f for f in os.listdir(processed_matrices_dir) if f"{patient_name}_REL" in f)
        rem_file = next(f for f in os.listdir(processed_matrices_dir) if f"{patient_name}_REM" in f)
    except StopIteration:
        print(f"Missing files for patient {patient_name}. Skipping...")
        continue

    dx_df = pd.read_csv(os.path.join(processed_matrices_dir, dx_file)).set_index("Gene").loc[top_degs]
    rel_df = pd.read_csv(os.path.join(processed_matrices_dir, rel_file)).set_index("Gene").loc[top_degs]
    rem_df = pd.read_csv(os.path.join(processed_matrices_dir, rem_file)).set_index("Gene").loc[top_degs]

    # Concatenate counts
    combined_matrix = np.hstack([dx_df.values, rel_df.values, rem_df.values])

    # Compute adjacency matrix
    adjacency_matrix = compute_spearman_adjacency(combined_matrix)

    # Perform BDM analysis for each threshold
    for threshold in thresholds:
        original_bdm, perturbed_bdm_values = bdm_analysis(adjacency_matrix, threshold)

        # Save results
        result_path = os.path.join(patient_bdm_dir, f"{patient_name}_bdm_threshold_{threshold}.csv")
        pd.DataFrame({
            "Gene": top_degs,
            "Perturbed_BDM": perturbed_bdm_values
        }).to_csv(result_path, index=False)

print("BDM analysis completed and results saved.")
# Out:
# Processing patient: AML10
# Processing patient: AML11
# Processing patient: AML15
# Processing patient: AML16
# Processing patient: AML21
# Processing patient: AML22
# Processing patient: AML24
# Processing patient: AML27
# Processing patient: AML2
# Processing patient: AML5
# Processing patient: AML6
# Processing patient: AML7
# Processing patient: AML8
# Processing patient: AML9
# BDM analysis completed and results saved.

# %%
##NNMF: transcriptional modules; hierarchical clustering

# %%
import os
import pandas as pd
import numpy as np
from sklearn.decomposition import NMF
from scipy.stats import spearmanr
from pybdm import BDM

# Initialize BDM object
bdm = BDM(ndim=2)

# Directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
nnmf_results_dir = "results/nnmf_analysis"
os.makedirs(nnmf_results_dir, exist_ok=True)

# Parameters
n_components = 5  # Number of transcriptional modules
top_genes_per_module = 50  # Top genes to keep per module for BDM analysis
thresholds = [0.1, 0.5]  # Thresholds for binarization

# Helper: Compute Spearman adjacency matrix
def compute_spearman_adjacency(data):
    adjacency = np.zeros((data.shape[0], data.shape[0]))
    for i in range(data.shape[0]):
        for j in range(i + 1, data.shape[0]):  # Avoid redundant computation
            corr, _ = spearmanr(data[i, :], data[j, :])
            adjacency[i, j] = corr
            adjacency[j, i] = corr  # Symmetric matrix
    return adjacency

# Helper: Perform BDM Perturbation Analysis
def bdm_analysis(matrix, threshold):
    binary_matrix = (matrix > threshold).astype(int)
    original_bdm = bdm.bdm(binary_matrix)

    # Node perturbation (set each node to 0)
    perturbed_bdm_values = []
    for i in range(binary_matrix.shape[0]):
        perturbed_matrix = binary_matrix.copy()
        perturbed_matrix[i, :] = 0
        perturbed_matrix[:, i] = 0
        perturbed_bdm_values.append(original_bdm - bdm.bdm(perturbed_matrix))

    return perturbed_bdm_values

# Helper: Apply NNMF
def apply_nnmf(expression_matrix, n_components):
    model = NMF(n_components=n_components, init="random", random_state=42, max_iter=1000)
    W = model.fit_transform(expression_matrix)
    H = model.components_
    return W, H

# Process each patient's data
patients = set([file.split("_")[1] for file in os.listdir(processed_matrices_dir) if file.endswith("_processed_matrix.csv")])

for patient_id in patients:
    print(f"Processing patient: {patient_id}")

    # Create directories
    patient_nnmf_dir = os.path.join(nnmf_results_dir, patient_id)
    patient_bdm_dir = os.path.join(patient_nnmf_dir, "bdm_results")
    os.makedirs(patient_nnmf_dir, exist_ok=True)
    os.makedirs(patient_bdm_dir, exist_ok=True)

    # Construct file paths and check existence
    try:
        dx_file = next(f for f in os.listdir(processed_matrices_dir) if f"_{patient_id}_DX_processed_matrix.csv" in f)
        rel_file = next(f for f in os.listdir(processed_matrices_dir) if f"_{patient_id}_REL_processed_matrix.csv" in f)
        rem_file = next(f for f in os.listdir(processed_matrices_dir) if f"_{patient_id}_REM_processed_matrix.csv" in f)
    except StopIteration:
        print(f"Missing one or more files for patient {patient_id}. Skipping...")
        continue

    dx_df = pd.read_csv(os.path.join(processed_matrices_dir, dx_file)).set_index("Gene")
    rel_df = pd.read_csv(os.path.join(processed_matrices_dir, rel_file)).set_index("Gene")
    rem_df = pd.read_csv(os.path.join(processed_matrices_dir, rem_file)).set_index("Gene")

    # Concatenate expression data
    combined_matrix = pd.concat([dx_df, rel_df, rem_df], axis=1).values
    gene_names = dx_df.index.values

    # Apply NNMF
    W, H = apply_nnmf(combined_matrix, n_components)

    # Identify top genes per module
    nnmf_results = []
    for module_idx in range(W.shape[1]):
        module_scores = W[:, module_idx]
        ranked_genes = np.argsort(module_scores)[::-1]  # Sort in descending order
        top_genes = ranked_genes[:top_genes_per_module]
        for gene_idx in top_genes:
            nnmf_results.append({
                "Module": module_idx + 1,
                "Gene": gene_names[gene_idx],
                "Score": module_scores[gene_idx]
            })

    nnmf_results_df = pd.DataFrame(nnmf_results)
    nnmf_results_df.to_csv(os.path.join(patient_nnmf_dir, f"{patient_id}_nnmf_top_genes.csv"), index=False)

    # Get unique top genes across modules for BDM
    unique_top_genes = nnmf_results_df["Gene"].unique()
    top_gene_matrix = pd.DataFrame(combined_matrix, index=gene_names).loc[unique_top_genes].values

    # Compute adjacency matrix for BDM
    adjacency_matrix = compute_spearman_adjacency(top_gene_matrix)

    # Perform BDM analysis for each threshold
    for threshold in thresholds:
        perturbed_bdm_values = bdm_analysis(adjacency_matrix, threshold)
        result_path = os.path.join(patient_bdm_dir, f"{patient_id}_bdm_threshold_{threshold}.csv")
        pd.DataFrame({
            "Gene": unique_top_genes,
            "Perturbed_BDM": perturbed_bdm_values
        }).to_csv(result_path, index=False)

print("NNMF and BDM analysis completed for all patients.")
# Out:
# Processing patient: AML11
# Processing patient: AML22
# Processing patient: AML27
# Processing patient: AML21
# Processing patient: AML7
# Processing patient: AML16
# Processing patient: AML9
# Processing patient: AML10
# Processing patient: AML6
# Processing patient: AML8
# C:\Users\uabic\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1759: ConvergenceWarning: Maximum number of iterations 1000 reached. Increase it to improve convergence.
#   warnings.warn(
# Processing patient: AML15
# Processing patient: AML24
# Processing patient: AML5
# Processing patient: AML2
# NNMF and BDM analysis completed for all patients.

# %%
###Bayesian Ridge Regression

# %%
import os
import numpy as np
import pandas as pd
from sklearn.linear_model import BayesianRidge
from sklearn.preprocessing import MinMaxScaler

# Directories
processed_matrices_dir = "GSE235063_RAW/processed_matrices_csv"
ridge_folder = "Bayesian_regression/Bayesian_Ridge"
os.makedirs(ridge_folder, exist_ok=True)

# Helper Function: Load and Process Patient Data
def load_patient_data(files):
    dx_file = files.get("DX")
    rel_file = files.get("REL")
    rem_file = files.get("REM")
    
    if not dx_file or not rel_file or not rem_file:
        raise ValueError("Missing one or more files (DX, REL, REM) for patient.")

    dx_df = pd.read_csv(os.path.join(processed_matrices_dir, dx_file))
    rel_df = pd.read_csv(os.path.join(processed_matrices_dir, rel_file))
    rem_df = pd.read_csv(os.path.join(processed_matrices_dir, rem_file))

    common_genes = set(dx_df["Gene"]).intersection(rel_df["Gene"]).intersection(rem_df["Gene"])
    dx_df = dx_df[dx_df["Gene"].isin(common_genes)].set_index("Gene")
    rel_df = rel_df[rel_df["Gene"].isin(common_genes)].set_index("Gene")
    rem_df = rem_df[rem_df["Gene"].isin(common_genes)].set_index("Gene")

    combined_data = pd.concat([dx_df.mean(axis=1), rel_df.mean(axis=1), rem_df.mean(axis=1)], axis=1)
    combined_data.columns = ["DX", "REL", "REM"]

    return combined_data

# Bayesian Ridge Regression
def bayesian_ridge_regression(patient, files):
    print(f"Processing Bayesian Ridge Regression for patient: {patient}...")
    data = load_patient_data(files)

    X = data.values.T  # Transpose to treat genes as samples
    y = np.arange(X.shape[0])  # Dummy labels for each gene

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    model = BayesianRidge()
    model.fit(X, y)

    feature_importance = pd.DataFrame({
        "Gene": data.index,
        "Importance": np.abs(model.coef_)
    }).sort_values(by="Importance", ascending=False)

    output_file = os.path.join(ridge_folder, f"{patient}_ridge_importance.csv")
    feature_importance.head(30).to_csv(output_file, index=False)  # Save top 30 features
    print(f"Saved Bayesian Ridge results for patient: {patient}")

# Organize files by patient
file_groups = {}
for file in os.listdir(processed_matrices_dir):
    if not file.endswith("_processed_matrix.csv"):
        continue
    parts = file.split("_")
    patient, state = parts[1], parts[2]
    file_groups.setdefault(patient, {})[state] = file

# Run Analysis for All Patients
for patient, files in file_groups.items():
    try:
        bayesian_ridge_regression(patient, files)
    except Exception as e:
        print(f"Error processing patient {patient}: {e}")

print("Bayesian Ridge Regression completed.")
# Out:
# Processing Bayesian Ridge Regression for patient: AML16...
# Saved Bayesian Ridge results for patient: AML16
# Processing Bayesian Ridge Regression for patient: AML6...
# Saved Bayesian Ridge results for patient: AML6
# Processing Bayesian Ridge Regression for patient: AML2...
# Saved Bayesian Ridge results for patient: AML2
# Processing Bayesian Ridge Regression for patient: AML15...
# Saved Bayesian Ridge results for patient: AML15
# Processing Bayesian Ridge Regression for patient: AML7...
# Saved Bayesian Ridge results for patient: AML7
# Processing Bayesian Ridge Regression for patient: AML8...
# Saved Bayesian Ridge results for patient: AML8
# Processing Bayesian Ridge Regression for patient: AML5...
# Saved Bayesian Ridge results for patient: AML5
# Processing Bayesian Ridge Regression for patient: AML27...
# Saved Bayesian Ridge results for patient: AML27
# Processing Bayesian Ridge Regression for patient: AML9...
# Saved Bayesian Ridge results for patient: AML9
# Processing Bayesian Ridge Regression for patient: AML10...
# Saved Bayesian Ridge results for patient: AML10
# Processing Bayesian Ridge Regression for patient: AML11...
# Saved Bayesian Ridge results for patient: AML11
# Processing Bayesian Ridge Regression for patient: AML22...
# Saved Bayesian Ridge results for patient: AML22
# Processing Bayesian Ridge Regression for patient: AML21...
# Saved Bayesian Ridge results for patient: AML21
# Processing Bayesian Ridge Regression for patient: AML24...
# Saved Bayesian Ridge results for patient: AML24
# Bayesian Ridge Regression completed.
